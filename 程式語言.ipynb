# %% [markdown]
# # 臺灣避孕方法使用率
# 20~49歲未曾結婚有性經驗婦女

# %%
import matplotlib.pyplot as plt

labels = ["保險套", "口服避孕藥" , "子宮避孕器" , "性交中斷體外射精法" ,"計算安全期"]
sizes = [95.7, 20.1, 9.5, 3, 20.6]
colors = ["red", "orange", "yellow", "purple", "pink"]
explode = (0, 0.1, 0, 0, 0)
plt.pie(sizes,explode = explode,labels=labels,colors = colors,\
       labeldistance = 1.1,autopct = "%3.1f%%",shadow = False,\
       startangle = 90,pctdistance = 0.6)
plt.axis("equal")
plt.legend()
plt.show()

# %% [markdown]
# # 大學註冊率

# %%
import matplotlib.pyplot as plt
import numpy as np
listx = [1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979]
listy = [2200,2209,2310,2428,2406,2555,2790,3026,2923,2882,3015]
plt.bar(listx,listy,label="Female")
plt.ylim([2100,3100])
plt.title("Enrollment of College of Women at Ages of 18-24")
plt.xlabel("Year")
plt.show()

# %% [markdown]
# # 專業領域學位人數：法學

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
tdata = pd.read_csv("new_dentistry_medicine_law.csv", encoding = "utf-8")
tdata
data = tdata.astype(float)
tdata[['Year', 'Law']].plot(kind = 'line', x = 'Year', y = 'Law' , title = "First-year Law Students", legend = True, color = 'red', ls = '--', lw = 2)

# %% [markdown]
# # 專業領域學位人數：牙科

# %%
tdata[['Year', 'Dentistry']].plot(kind = 'line', x = 'Year', y = 'Dentistry' , title = "First-year Dentistry Students", legend = True, ls = '-.', lw = 2)

# %% [markdown]
# # 專業領域學位人數：藥學

# %%
tdata[['Year', 'Medicine']].plot(kind = 'line', x = 'Year', y = 'Medicine' , title = "First-year Medicine Students", legend = True, color = 'green', lw = 2)

# %% [markdown]
# # 專業領域學位人數：商管學

# %%
gdata = pd.read_csv("new_business.csv", encoding = "utf-8")
gdata
gdata = gdata.astype(float)
gdata[['Year', "Business Management and Administrative Services"]].plot(kind = 'line', x = 'Year', y = "Business Management and Administrative Services" , 
                                         title = "Earned degrees in business management and administrative services", 
                                         legend = True, 
                                         color = 'purple', 
                                         ls = '-', 
                                         lw = 2)
plt.show()

# %% [markdown]
# # 美國通過降低成人年齡的累計州數

# %%
import matplotlib.pyplot as plt
import numpy as np
listx = [1969,1970,1971,1972,1973,1974,1975,1976,1977,1978,1979]
listy = [11,14,26,41,46,49,50,51,51,51,51]
plt.bar(listx,listy,label="Female")
plt.ylim([0,60])
plt.xlabel("Year")
plt.ylabel("the number of states")
plt.show()
